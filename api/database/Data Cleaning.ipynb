# %%
import pandas as pd
from pymongo import MongoClient
from dotenv import load_dotenv
import os
import json

# %%
user = os.getenv('USER')
password= os.getenv('PASSWORD')
url = f"mongodb+srv://{user}:{password}@cluster0.rdiud.mongodb.net/test"
connection = MongoClient(url)
db = connection["Mid_project"]
euro = db.Euro2020

# %%
df = pd.read_csv("eurocup_2020_results.csv")
df
# Out:
#                         stage          date   pens pens_home_score  \
# 0                      Final     11.07.2021   True               3
# 1                Semi-finals    07.07.2021   False           False
# 2                Semi-finals     06.07.2021   True               4
# 3             Quarter-finals    03.07.2021   False           False
# 4             Quarter-finals    03.07.2021   False           False
# 5             Quarter-finals    02.07.2021   False           False
# 6             Quarter-finals     02.07.2021   True               1
# 7                Round of 16    29.06.2021   False           False
# 8                Round of 16    29.06.2021   False           False
# 9                Round of 16     28.06.2021   True               4
# 10               Round of 16    28.06.2021   False           False
# 11               Round of 16    27.06.2021   False           False
# 12               Round of 16    27.06.2021   False           False
# ...

# %%
# Out:
# [
# {
# '
# P
# l
# a
# y
# e
# r
# _
# N
# a
# m
# e
# '
# :
#
# '
# I
# n
# s
# i
# g
# n
# e
# '
# ,
#
# '
# P
# l
# a
# y
# e
# r
# _
# N
# u
# m
# b
# e
# r
# '
# :
#
# '
# 1
# 0
# '
# }
# ,
#
# {
# '
# P
# l
# a
# y
# e
# r
# _
# N
# a
# m
# e
# '
# :
#
# '
# I
# m
# m
# o
# b
# i
# l
# e
# '
# ,
#
# '
# P
# l
# a
# y
# e
# r
# _
# N
# u
# m
# b
# e
# r
# '
# :
#
# '
# 1
# 7
# '
# }
# ,
#
# {
# '
# P
# l
# a
# y
# e
# r
# _
# N
# a
# m
# e
# '
# :
#
# '
# C
# h
# i
# e
# s
# a
# '
# ,
#
# '
# P
# l
# a
# y
# e
# r
# _
# N
# u
# m
# b
# e
# r
# '
# :
#
# '
# 1
# 4
# '
# }
# ,
#
# {
# '
# P
# l
# a
# y
# e
# r
# _
# N
# a
# m
# e
# '
# :
#
# '
# V
# e
# r
# r
# a
# t
# t
# i
# '
# ,
#
# '
# P
# l
# a
# y
# e
# r
# _
# N
# u
# m
# b
# e
# r
# '
# :
#
# '
# 6
# '
# }
# ,
#
# {
# '
# P
# l
# a
# y
# e
# r
# _
# N
# a
# m
# e
# '
# :
#
# '
# J
# o
# r
# g
# i
# n
# h
# o
# '
# ,
#
# '
# P
# l
# a
# y
# e
# r
# _
# N
# u
# m
# b
# e
# r
# '
# :
#
# '
# 8
# '
# }
# ,
#
# {
# '
# P
# l
# ...

# %%
df = df.drop(columns = ["duels_won_home","duels_won_away"])

# %%
dict_mongo = df.to_dict(orient = "records")

# %%
euro.insert_many(dict_mongo)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13440/651332029.py in <module>
# ----> 1 list(euro.find({"stage":" Final "},{'events_list':1}.distinct('events_list')))
#
# AttributeError: 'dict' object has no attribute 'distinct'
