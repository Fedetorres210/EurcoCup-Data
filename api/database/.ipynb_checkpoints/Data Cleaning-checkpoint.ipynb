# %%
import pandas as pd
from pymongo import MongoClient
from dotenv import load_dotenv
import os

# %%
df = pd.read_csv("eurocup_2020_results.csv")
df
# Out:
#                         stage          date   pens pens_home_score  \
# 0                      Final     11.07.2021   True               3
# 1                Semi-finals    07.07.2021   False           False
# 2                Semi-finals     06.07.2021   True               4
# 3             Quarter-finals    03.07.2021   False           False
# 4             Quarter-finals    03.07.2021   False           False
# 5             Quarter-finals    02.07.2021   False           False
# 6             Quarter-finals     02.07.2021   True               1
# 7                Round of 16    29.06.2021   False           False
# 8                Round of 16    29.06.2021   False           False
# 9                Round of 16     28.06.2021   True               4
# 10               Round of 16    28.06.2021   False           False
# 11               Round of 16    27.06.2021   False           False
# 12               Round of 16    27.06.2021   False           False
# ...

# %%
df = df.drop(columns = ["duels_won_home","duels_won_away"])

# %%
dict_mongo = df.to_dict()
dict_mongo
# Out:
# {'stage': {0: ' Final ',
#   1: ' Semi-finals ',
#   2: ' Semi-finals ',
#   3: ' Quarter-finals ',
#   4: ' Quarter-finals ',
#   5: ' Quarter-finals ',
#   6: ' Quarter-finals ',
#   7: ' Round of 16 ',
#   8: ' Round of 16 ',
#   9: ' Round of 16 ',
#   10: ' Round of 16 ',
#   11: ' Round of 16 ',
#   12: ' Round of 16 ',
#   13: ' Round of 16 ',
#   14: ' Round of 16 ',
#   15: ' Group stage: Matchday 3 ',
#   16: ' Group stage: Matchday 3 ',
#   17: ' Group stage: Matchday 3 ',
#   18: ' Group stage: Matchday 3 ',
#   19: ' Group stage: Matchday 3 ',
#   20: ' Group stage: Matchday 3 ',
#   21: ' Group stage: Matchday 3 ',
#   22: ' Group stage: Matchday 3 ',
#   23: ' Group stage: Matchday 3 ',
#   24: ' Group stage: Matchday 3 ',
#   25: ' Group stage: Matchday 3 ',
#   26: ' Group stage: Matchday 3 ',
#   27: ' Group stage: Matchday 2 ',
#   28: ' Group stage: Matchday 2 ',
#   29: ' Group stage: Matchday 2 ',
#   30: ' Group stage: Matchday 2 ',
# ...

# %%
load_dotenv()
user = os.getenv('USER')
password = os.getenv('PASSWORD')
url = 'mongodb+srv://user:password@cluster0.rdiud.mongodb.net/test'
connection = MongoClient(url)
user

# %%
database = connection["Mid_project"]

# %%
eurocope = database.Eurocope
eurocope.insert_one(dict_mongo)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22328/2781647929.py in <module>
#       1 eurocope = database.Eurocope
# ----> 2 eurocope.insert_one(dict_mongo)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     522         write_concern = self._write_concern_for(session)
#     523         return InsertOneResult(
# --> 524             self._insert_one(
#     525                 document, ordered=True, check_keys=False,
#     526                 write_concern=write_concern, op_id=None,
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, write_concern, op_id, bypass_doc_val, session)
#     472             _check_write_command_response(result)
#     473
# ...
